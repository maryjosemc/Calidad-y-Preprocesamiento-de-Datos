# %%
install.packages("dlookr")
# Out:
# Installing package into 'D:/Documentos/R/win-library/3.6'
# (as 'lib' is unspecified)
#
# also installing the dependencies 'desc', 'pkgbuild', 'rprojroot', 'pkgload', 'praise', 'reshape2', 'testthat', 'lme4', 'latticeExtra', 'acepack', 'data.table', 'htmlTable', 'viridis', 'forcats', 'hms', 'cellranger', 'progress', 'httr', 'selectr', 'clipr', 'callr', 'proto', 'RSQLite', 'DBI', 'chron', 'libcoin', 'mvtnorm', 'inum', 'TTR', 'curl', 'gplots', 'broom', 'pkgconfig', 'R6', 'BH', 'plogr', 'stringi', 'lifecycle', 'gtable', 'isoband', 'scales', 'withr', 'car', 'sandwich', 'abind', 'colorspace', 'Hmisc', 'e1071', 'haven', 'readstata13', 'readxl', 'nortest', 'stringr', 'xml2', 'rvest', 'readr', 'viridisLite', 'rstudioapi', 'webshot', 'sqldf', 'partykit', 'Formula', 'gsubfn', 'highr', 'markdown', 'yaml', 'xfun', 'mime', 'xts', 'quantmod', 'zoo', 'ROCR', 'mice', 'dplyr', 'magrittr', 'tidyr', 'ggplot2', 'RcmdrMisc', 'corrplot', 'purrr', 'tibble', 'tidyselect', 'classInt', 'moments', 'kableExtra', 'prettydoc', 'smbinning', 'xtable', 'knitr', 'rmarkdown', 'RColorBrewer', 'gridExtra', 'tinytex', 'DMwR'
#   There are binary versions available but the source versions are later:
#           binary source needs_compilation
# lifecycle  0.1.0  0.2.0             FALSE
# partykit   1.2-6  1.2-7              TRUE
# dplyr      0.8.4  0.8.5              TRUE
# ggplot2    3.2.1  3.3.0             FALSE
#
#   Binaries will be installed
# Warning message in download.file(url, destfile, method, mode = "wb", ...):
# "fallo en InternetOpenUrl: 'Se agotó el tiempo de espera para la operación'"
# Error in download.file(url, destfile, method, mode = "wb", ...) :
#   no fue posible abrir la URL 'https://cran.r-project.org/bin/windows/contrib/3.6/zoo_1.8-7.zip'
# Warning message in download.packages(pkgs, destdir = tmpd, available = available, :
# "download of package 'zoo' failed"
# package 'desc' successfully unpacked and MD5 sums checked
# package 'pkgbuild' successfully unpacked and MD5 sums checked
# package 'rprojroot' successfully unpacked and MD5 sums checked
# package 'pkgload' successfully unpacked and MD5 sums checked
# package 'praise' successfully unpacked and MD5 sums checked
# package 'reshape2' successfully unpacked and MD5 sums checked
# package 'testthat' successfully unpacked and MD5 sums checked
# package 'lme4' successfully unpacked and MD5 sums checked
# package 'latticeExtra' successfully unpacked and MD5 sums checked
# package 'acepack' successfully unpacked and MD5 sums checked
# package 'data.table' successfully unpacked and MD5 sums checked
# package 'htmlTable' successfully unpacked and MD5 sums checked
# package 'viridis' successfully unpacked and MD5 sums checked
# package 'forcats' successfully unpacked and MD5 sums checked
# package 'hms' successfully unpacked and MD5 sums checked
# package 'cellranger' successfully unpacked and MD5 sums checked
# package 'progress' successfully unpacked and MD5 sums checked
# package 'httr' successfully unpacked and MD5 sums checked
# package 'selectr' successfully unpacked and MD5 sums checked
# package 'clipr' successfully unpacked and MD5 sums checked
# package 'callr' successfully unpacked and MD5 sums checked
# package 'proto' successfully unpacked and MD5 sums checked
# package 'RSQLite' successfully unpacked and MD5 sums checked
# package 'DBI' successfully unpacked and MD5 sums checked
# package 'chron' successfully unpacked and MD5 sums checked
# package 'libcoin' successfully unpacked and MD5 sums checked
# package 'mvtnorm' successfully unpacked and MD5 sums checked
# package 'inum' successfully unpacked and MD5 sums checked
# package 'TTR' successfully unpacked and MD5 sums checked
# package 'curl' successfully unpacked and MD5 sums checked
# package 'gplots' successfully unpacked and MD5 sums checked
# package 'broom' successfully unpacked and MD5 sums checked
# package 'pkgconfig' successfully unpacked and MD5 sums checked
# package 'R6' successfully unpacked and MD5 sums checked
# package 'BH' successfully unpacked and MD5 sums checked
# package 'plogr' successfully unpacked and MD5 sums checked
# package 'stringi' successfully unpacked and MD5 sums checked
# package 'gtable' successfully unpacked and MD5 sums checked
# package 'isoband' successfully unpacked and MD5 sums checked
# package 'scales' successfully unpacked and MD5 sums checked
# package 'withr' successfully unpacked and MD5 sums checked
# package 'car' successfully unpacked and MD5 sums checked
# package 'sandwich' successfully unpacked and MD5 sums checked
# package 'abind' successfully unpacked and MD5 sums checked
# package 'colorspace' successfully unpacked and MD5 sums checked
# package 'Hmisc' successfully unpacked and MD5 sums checked
# package 'e1071' successfully unpacked and MD5 sums checked
# package 'haven' successfully unpacked and MD5 sums checked
# package 'readstata13' successfully unpacked and MD5 sums checked
# package 'readxl' successfully unpacked and MD5 sums checked
# package 'nortest' successfully unpacked and MD5 sums checked
# package 'stringr' successfully unpacked and MD5 sums checked
# package 'xml2' successfully unpacked and MD5 sums checked
# package 'rvest' successfully unpacked and MD5 sums checked
# package 'readr' successfully unpacked and MD5 sums checked
# package 'viridisLite' successfully unpacked and MD5 sums checked
# package 'rstudioapi' successfully unpacked and MD5 sums checked
# package 'webshot' successfully unpacked and MD5 sums checked
# package 'sqldf' successfully unpacked and MD5 sums checked
# package 'partykit' successfully unpacked and MD5 sums checked
# package 'Formula' successfully unpacked and MD5 sums checked
# package 'gsubfn' successfully unpacked and MD5 sums checked
# package 'highr' successfully unpacked and MD5 sums checked
# package 'markdown' successfully unpacked and MD5 sums checked
# package 'yaml' successfully unpacked and MD5 sums checked
# package 'xfun' successfully unpacked and MD5 sums checked
# package 'mime' successfully unpacked and MD5 sums checked
# package 'xts' successfully unpacked and MD5 sums checked
# package 'quantmod' successfully unpacked and MD5 sums checked
# package 'ROCR' successfully unpacked and MD5 sums checked
# package 'mice' successfully unpacked and MD5 sums checked
# package 'dplyr' successfully unpacked and MD5 sums checked
# package 'magrittr' successfully unpacked and MD5 sums checked
# package 'tidyr' successfully unpacked and MD5 sums checked
# package 'RcmdrMisc' successfully unpacked and MD5 sums checked
# package 'corrplot' successfully unpacked and MD5 sums checked
# package 'purrr' successfully unpacked and MD5 sums checked
# package 'tibble' successfully unpacked and MD5 sums checked
# package 'tidyselect' successfully unpacked and MD5 sums checked
# package 'classInt' successfully unpacked and MD5 sums checked
# package 'moments' successfully unpacked and MD5 sums checked
# package 'kableExtra' successfully unpacked and MD5 sums checked
# package 'prettydoc' successfully unpacked and MD5 sums checked
# package 'smbinning' successfully unpacked and MD5 sums checked
# package 'xtable' successfully unpacked and MD5 sums checked
# package 'knitr' successfully unpacked and MD5 sums checked
# package 'rmarkdown' successfully unpacked and MD5 sums checked
# package 'RColorBrewer' successfully unpacked and MD5 sums checked
# package 'gridExtra' successfully unpacked and MD5 sums checked
# package 'tinytex' successfully unpacked and MD5 sums checked
# package 'DMwR' successfully unpacked and MD5 sums checked
# package 'dlookr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Mary\AppData\Local\Temp\RtmpIXmZC9\downloaded_packages
# installing the source packages 'lifecycle', 'ggplot2'

# %%
library("dlookr")
# Out:
# Loading required package: mice
#
#
# Attaching package: 'mice'
#
#
# The following objects are masked from 'package:base':
#
#     cbind, rbind
#
#
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
#
#
# Attaching package: 'dlookr'
#
#
# The following object is masked from 'package:base':
#
#     transform

# %%
library("dlookr")

# %%
delim = ','
dec = '.'

# %%
data <- read.csv("concentradohogar.csv")

# %%
diagnose(data)
# Out:
#     variables   types   missing_count missing_percent unique_count unique_rate
# 1   ï..folioviv numeric 0             0               73405        9.833617e-01
# 2   foliohog    integer 0             0                   5        6.698193e-05
# 3   ubica_geo   integer 0             0                 996        1.334280e-02
# 4   tam_loc     integer 0             0                   4        5.358554e-05
# 5   est_socio   integer 0             0                   4        5.358554e-05
# 6   est_dis     integer 0             0                 543        7.274237e-03
# 7   upm         integer 0             0                8377        1.122215e-01
# 8   factor      integer 0             0                1747        2.340349e-02
# 9   clase_hog   integer 0             0                   5        6.698193e-05
# 10  sexo_jefe   integer 0             0                   2        2.679277e-05
# 11  edad_jefe   integer 0             0                  94        1.259260e-03
# 12  educa_jefe  integer 0             0                  11        1.473602e-04
# 13  tot_integ   integer 0             0                  20        2.679277e-04
# 14  hombres     integer 0             0                  12        1.607566e-04
# 15  mujeres     integer 0             0                  13        1.741530e-04
# 16  mayores     integer 0             0                  14        1.875494e-04
# 17  menores     integer 0             0                  11        1.473602e-04
# 18  p12_64      integer 0             0                  14        1.875494e-04
# 19  p65mas      integer 0             0                   6        8.037831e-05
# 20  ocupados    integer 0             0                  12        1.607566e-04
# 21  percep_ing  integer 0             0                  15        2.009458e-04
# 22  perc_ocupa  integer 0             0                  12        1.607566e-04
# 23  ing_cor     numeric 0             0               70771        9.480756e-01
# 24  ingtrab     numeric 0             0               44877        6.011896e-01
# 25  trabajo     numeric 0             0               31428        4.210216e-01
# 26  sueldos     numeric 0             0               13914        1.863973e-01
# 27  horas_extr  numeric 0             0                1607        2.152799e-02
# 28  comisiones  numeric 0             0                1977        2.648465e-02
# 29  aguinaldo   numeric 0             0                3535        4.735622e-02
# 30  indemtrab   numeric 0             0                 406        5.438933e-03
# ... ...         ...     ...           ...             ...          ...
# 97  refaccion   numeric 0             0                2032        2.722146e-02
# 98  combus      numeric 0             0                2738        3.667930e-02
# 99  comunica    numeric 0             0                5831        7.811432e-02
# 100 educa_espa  numeric 0             0               25259        3.383793e-01
# 101 educacion   numeric 0             0               13036        1.746353e-01
# 102 esparci     numeric 0             0                9719        1.301995e-01
# 103 paq_turist  numeric 0             0                 696        9.323884e-03
# 104 personales  numeric 0             0               35552        4.762683e-01
# 105 cuida_pers  numeric 0             0               12595        1.687275e-01
# 106 acces_pers  numeric 0             0                1477        1.978646e-02
# 107 otros_gas   numeric 0             0                4350        5.827428e-02
# 108 transf_gas  numeric 0             0                6691        8.963522e-02
# 109 percep_tot  numeric 0             0               16219        2.172760e-01
# 110 retiro_inv  numeric 0             0                1165        1.560679e-02
# 111 prestamos   numeric 0             0                 670        8.975578e-03
# 112 otras_perc  numeric 0             0                1091        1.461546e-02
# 113 ero_nm_viv  numeric 0             0                 301        4.032312e-03
# 114 ero_nm_hog  numeric 0             0               11239        1.505620e-01
# 115 erogac_tot  numeric 0             0               13833        1.853122e-01
# 116 cuota_viv   numeric 0             0                 613        8.211984e-03
# 117 mater_serv  numeric 0             0                2199        2.945865e-02
# 118 material    numeric 0             0                1701        2.278725e-02
# 119 servicio    numeric 0             0                 523        7.006310e-03
# 120 deposito    numeric 0             0                1897        2.541294e-02
# 121 prest_terc  numeric 0             0                 482        6.457058e-03
# 122 pago_tarje  numeric 0             0                1899        2.543974e-02
# 123 deudas      numeric 0             0                1885        2.525219e-02
# 124 balance     numeric 0             0                3641        4.877624e-02
# 125 otras_erog  numeric 0             0                1590        2.130025e-02
# 126 smg         numeric 0             0                   1        1.339639e-05

# %%
dim(data)
# Out:
# [1] 900  10

# %%
diagnose_outlier(data)
# Out:
#     variables   outliers_cnt outliers_ratio outliers_mean with_mean
# 1   ï..folioviv     0         0.0000000              NaN  1.615773e+09
# 2   foliohog     1242         1.6638311     2.168277e+00  1.019438e+00
# 3   ubica_geo       0         0.0000000              NaN  1.594090e+04
# 4   tam_loc         0         0.0000000              NaN  2.541817e+00
# 5   est_socio   35362        47.3722990     2.118376e+00  2.056077e+00
# 6   est_dis         0         0.0000000              NaN  2.553638e+02
# 7   upm             0         0.0000000              NaN  4.299807e+03
# 8   factor       4643         6.2199419     1.902860e+03  4.654550e+02
# 9   clase_hog     275         0.3684006     5.000000e+00  2.147923e+00
# 10  sexo_jefe       0         0.0000000              NaN  1.274304e+00
# 11  edad_jefe      99         0.1326242     9.841414e+01  4.979609e+01
# 12  educa_jefe      0         0.0000000              NaN  5.525835e+00
# 13  tot_integ     549         0.7354616     1.112568e+01  3.604499e+00
# 14  hombres      5613         7.5193913     4.422412e+00  1.763554e+00
# 15  mujeres      6429         8.6125363     4.476279e+00  1.840945e+00
# 16  mayores       417         0.5586293     8.637890e+00  2.843503e+00
# 17  menores      4893         6.5548515     3.296546e+00  7.609951e-01
# 18  p12_64      12963        17.3657347     3.057471e+00  2.541026e+00
# 19  p65mas      17279        23.1476148     1.306731e+00  3.024770e-01
# 20  ocupados     4668         6.2534328     4.405313e+00  1.695540e+00
# 21  percep_ing    788         1.0556352     7.609137e+00  2.419133e+00
# 22  perc_ocupa   4135         5.5394055     4.379444e+00  1.650153e+00
# 23  ing_cor      4700         6.2963013     1.804639e+05  4.604388e+04
# 24  ingtrab      3932         5.2674588     1.368533e+05  3.083953e+04
# 25  trabajo      3304         4.4261658     1.330476e+05  2.584474e+04
# 26  sueldos      2995         4.0122175     1.158435e+05  2.209531e+04
# 27  horas_extr   6262         8.3888167     3.013697e+03  2.528135e+02
# 28  comisiones   5861         7.8516216     9.211720e+03  7.232694e+02
# 29  aguinaldo    9306        12.4666765     6.812339e+03  1.162294e+03
# 30  indemtrab    1319         1.7669833     6.668577e+03  1.178326e+02
# ... ...         ...          ...            ...           ...
# 97  refaccion   12703        17.0174287      1151.2158     195.90732
# 98  combus       5451         7.3023698     12256.3425    2114.11273
# 99  comunica     3706         4.9647005      6795.0590    1227.03341
# 100 educa_espa   7811        10.4639168     18573.5565    3228.98438
# 101 educacion   10235        13.7112007     12543.3550    2235.12334
# 102 esparci      6927         9.2796763      4725.7220     718.12450
# 103 paq_turist   4713         6.3137166      4367.2619     275.73654
# 104 personales   5549         7.4336544     10019.9472    2219.80889
# 105 cuida_pers   4433         5.9386178      6843.8783    1700.10938
# 106 acces_pers  16034        21.4797648       432.5345      92.90739
# 107 otros_gas   17166        22.9962356      1855.9216     426.79211
# 108 transf_gas  14933        20.0048227      4176.8409     849.96511
# 109 percep_tot   7992        10.7063914     24199.6994    3404.85445
# 110 retiro_inv   7566        10.1357054      7509.4114     761.13182
# 111 prestamos    5315         7.1201790      6721.2467     478.56479
# 112 otras_perc   5010         6.7115892     12762.4713     856.56465
# 113 ero_nm_viv    655         0.8774633      3459.8849      30.35922
# 114 ero_nm_hog   9279        12.4305062      7581.9399    1278.23398
# 115 erogac_tot   9710        13.0078905     29351.1573    4837.89815
# 116 cuota_viv    5748         7.7002425      8066.4443     621.13577
# 117 mater_serv   8364        11.2047370      2885.0608     323.26348
# 118 material     6969         9.3359412      2166.3871     202.25262
# 119 servicio     3475         4.6552440      2599.4524     121.01085
# 120 deposito    14921        19.9887470      9549.3979    1908.80499
# 121 prest_terc   2327         3.1173389      2627.6668      81.91328
# 122 pago_tarje   7118         9.5355473      7737.8279     737.84424
# 123 deudas       6374         8.5388562      5356.9585     457.42298
# 124 balance      6672         8.9380685      3631.4629     324.58264
# 125 otras_erog   4430         5.9345988      6452.5130     382.93076
# 126 smg             0         0.0000000            NaN    7952.40000
#     without_mean
# 1   1.615773e+09
# 2   1.000000e+00
# 3   1.594090e+04
# 4   2.541817e+00
# 5   2.000000e+00
# 6   2.553638e+02
# 7   4.299807e+03
# 8   3.701194e+02
# 9   2.137377e+00
# 10  1.274304e+00
# 11  4.973153e+01
# 12  5.525835e+00
# 13  3.548773e+00
# 14  1.547368e+00
# 15  1.592586e+00
# 16  2.810952e+00
# 17  5.831350e-01
# 18  2.432495e+00
# 19  0.000000e+00
# 20  1.514783e+00
# 21  2.363761e+00
# 22  1.490101e+00
# 23  3.701169e+04
# 24  2.494479e+04
# 25  2.088002e+04
# 26  1.817671e+04
# 27  0.000000e+00
# 28  0.000000e+00
# 29  3.576030e+02
# 30  0.000000e+00
# ... ...
# 97     0.00000
# 98  1315.14610
# 99   936.15644
# 100 1435.69255
# 101  597.15603
# 102  308.19202
# 103    0.00000
# 104 1593.40918
# 105 1375.35467
# 106    0.00000
# 107    0.00000
# 108   17.99545
# 109  911.53211
# 110    0.00000
# 111    0.00000
# 112    0.00000
# 113    0.00000
# 114  383.42172
# 115 1172.44169
# 116    0.00000
# 117    0.00000
# 118    0.00000
# 119    0.00000
# 120    0.00000
# 121    0.00000
# 122    0.00000
# 123    0.00000
# 124    0.00000
# 125    0.00000
# 126 7952.40000

# %%
diagnose_outlier(data) 
  filter(outliers_cnt > 0)
# Out:
#     variables   outliers_cnt outliers_ratio outliers_mean with_mean
# 1   ï..folioviv     0         0.0000000              NaN  1.615773e+09
# 2   foliohog     1242         1.6638311     2.168277e+00  1.019438e+00
# 3   ubica_geo       0         0.0000000              NaN  1.594090e+04
# 4   tam_loc         0         0.0000000              NaN  2.541817e+00
# 5   est_socio   35362        47.3722990     2.118376e+00  2.056077e+00
# 6   est_dis         0         0.0000000              NaN  2.553638e+02
# 7   upm             0         0.0000000              NaN  4.299807e+03
# 8   factor       4643         6.2199419     1.902860e+03  4.654550e+02
# 9   clase_hog     275         0.3684006     5.000000e+00  2.147923e+00
# 10  sexo_jefe       0         0.0000000              NaN  1.274304e+00
# 11  edad_jefe      99         0.1326242     9.841414e+01  4.979609e+01
# 12  educa_jefe      0         0.0000000              NaN  5.525835e+00
# 13  tot_integ     549         0.7354616     1.112568e+01  3.604499e+00
# 14  hombres      5613         7.5193913     4.422412e+00  1.763554e+00
# 15  mujeres      6429         8.6125363     4.476279e+00  1.840945e+00
# 16  mayores       417         0.5586293     8.637890e+00  2.843503e+00
# 17  menores      4893         6.5548515     3.296546e+00  7.609951e-01
# 18  p12_64      12963        17.3657347     3.057471e+00  2.541026e+00
# 19  p65mas      17279        23.1476148     1.306731e+00  3.024770e-01
# 20  ocupados     4668         6.2534328     4.405313e+00  1.695540e+00
# 21  percep_ing    788         1.0556352     7.609137e+00  2.419133e+00
# 22  perc_ocupa   4135         5.5394055     4.379444e+00  1.650153e+00
# 23  ing_cor      4700         6.2963013     1.804639e+05  4.604388e+04
# 24  ingtrab      3932         5.2674588     1.368533e+05  3.083953e+04
# 25  trabajo      3304         4.4261658     1.330476e+05  2.584474e+04
# 26  sueldos      2995         4.0122175     1.158435e+05  2.209531e+04
# 27  horas_extr   6262         8.3888167     3.013697e+03  2.528135e+02
# 28  comisiones   5861         7.8516216     9.211720e+03  7.232694e+02
# 29  aguinaldo    9306        12.4666765     6.812339e+03  1.162294e+03
# 30  indemtrab    1319         1.7669833     6.668577e+03  1.178326e+02
# ... ...         ...          ...            ...           ...
# 97  refaccion   12703        17.0174287      1151.2158     195.90732
# 98  combus       5451         7.3023698     12256.3425    2114.11273
# 99  comunica     3706         4.9647005      6795.0590    1227.03341
# 100 educa_espa   7811        10.4639168     18573.5565    3228.98438
# 101 educacion   10235        13.7112007     12543.3550    2235.12334
# 102 esparci      6927         9.2796763      4725.7220     718.12450
# 103 paq_turist   4713         6.3137166      4367.2619     275.73654
# 104 personales   5549         7.4336544     10019.9472    2219.80889
# 105 cuida_pers   4433         5.9386178      6843.8783    1700.10938
# 106 acces_pers  16034        21.4797648       432.5345      92.90739
# 107 otros_gas   17166        22.9962356      1855.9216     426.79211
# 108 transf_gas  14933        20.0048227      4176.8409     849.96511
# 109 percep_tot   7992        10.7063914     24199.6994    3404.85445
# 110 retiro_inv   7566        10.1357054      7509.4114     761.13182
# 111 prestamos    5315         7.1201790      6721.2467     478.56479
# 112 otras_perc   5010         6.7115892     12762.4713     856.56465
# 113 ero_nm_viv    655         0.8774633      3459.8849      30.35922
# 114 ero_nm_hog   9279        12.4305062      7581.9399    1278.23398
# 115 erogac_tot   9710        13.0078905     29351.1573    4837.89815
# 116 cuota_viv    5748         7.7002425      8066.4443     621.13577
# 117 mater_serv   8364        11.2047370      2885.0608     323.26348
# 118 material     6969         9.3359412      2166.3871     202.25262
# 119 servicio     3475         4.6552440      2599.4524     121.01085
# 120 deposito    14921        19.9887470      9549.3979    1908.80499
# 121 prest_terc   2327         3.1173389      2627.6668      81.91328
# 122 pago_tarje   7118         9.5355473      7737.8279     737.84424
# 123 deudas       6374         8.5388562      5356.9585     457.42298
# 124 balance      6672         8.9380685      3631.4629     324.58264
# 125 otras_erog   4430         5.9345988      6452.5130     382.93076
# 126 smg             0         0.0000000            NaN    7952.40000
#     without_mean
# 1   1.615773e+09
# 2   1.000000e+00
# 3   1.594090e+04
# 4   2.541817e+00
# 5   2.000000e+00
# 6   2.553638e+02
# 7   4.299807e+03
# 8   3.701194e+02
# 9   2.137377e+00
# 10  1.274304e+00
# 11  4.973153e+01
# 12  5.525835e+00
# 13  3.548773e+00
# 14  1.547368e+00
# 15  1.592586e+00
# 16  2.810952e+00
# 17  5.831350e-01
# 18  2.432495e+00
# 19  0.000000e+00
# 20  1.514783e+00
# 21  2.363761e+00
# 22  1.490101e+00
# 23  3.701169e+04
# 24  2.494479e+04
# 25  2.088002e+04
# 26  1.817671e+04
# 27  0.000000e+00
# 28  0.000000e+00
# 29  3.576030e+02
# 30  0.000000e+00
# ... ...
# 97     0.00000
# 98  1315.14610
# 99   936.15644
# 100 1435.69255
# 101  597.15603
# 102  308.19202
# 103    0.00000
# 104 1593.40918
# 105 1375.35467
# 106    0.00000
# 107    0.00000
# 108   17.99545
# 109  911.53211
# 110    0.00000
# 111    0.00000
# 112    0.00000
# 113    0.00000
# 114  383.42172
# 115 1172.44169
# 116    0.00000
# 117    0.00000
# 118    0.00000
# 119    0.00000
# 120    0.00000
# 121    0.00000
# 122    0.00000
# 123    0.00000
# 124    0.00000
# 125    0.00000
# 126 7952.40000
# Error in as.ts(x): objeto 'outliers_cnt' no encontrado
# Traceback:
#
# 1. filter(outliers_cnt > 0)
# 2. as.ts(x)

# %%
plot_outlier(data)
# Out:
# Plot with title "Outlier Diagnosis Plot (ï..folioviv)"
# Plot with title "Outlier Diagnosis Plot (foliohog)"
# Plot with title "Outlier Diagnosis Plot (ubica_geo)"
# Plot with title "Outlier Diagnosis Plot (tam_loc)"
# Plot with title "Outlier Diagnosis Plot (est_socio)"
# Plot with title "Outlier Diagnosis Plot (est_dis)"
# Plot with title "Outlier Diagnosis Plot (upm)"
# Plot with title "Outlier Diagnosis Plot (factor)"
# Plot with title "Outlier Diagnosis Plot (clase_hog)"
# Plot with title "Outlier Diagnosis Plot (sexo_jefe)"
# Plot with title "Outlier Diagnosis Plot (edad_jefe)"
# Plot with title "Outlier Diagnosis Plot (educa_jefe)"
# Plot with title "Outlier Diagnosis Plot (tot_integ)"
# Plot with title "Outlier Diagnosis Plot (hombres)"
# Plot with title "Outlier Diagnosis Plot (mujeres)"
# Plot with title "Outlier Diagnosis Plot (mayores)"
# Plot with title "Outlier Diagnosis Plot (menores)"
# Plot with title "Outlier Diagnosis Plot (p12_64)"
# Plot with title "Outlier Diagnosis Plot (p65mas)"
# Plot with title "Outlier Diagnosis Plot (ocupados)"
# Plot with title "Outlier Diagnosis Plot (percep_ing)"
# Plot with title "Outlier Diagnosis Plot (perc_ocupa)"
# Plot with title "Outlier Diagnosis Plot (ing_cor)"
# Plot with title "Outlier Diagnosis Plot (ingtrab)"
# Plot with title "Outlier Diagnosis Plot (trabajo)"
# Plot with title "Outlier Diagnosis Plot (sueldos)"
# Plot with title "Outlier Diagnosis Plot (horas_extr)"
# Plot with title "Outlier Diagnosis Plot (comisiones)"
# Plot with title "Outlier Diagnosis Plot (aguinaldo)"
# Plot with title "Outlier Diagnosis Plot (indemtrab)"
# Plot with title "Outlier Diagnosis Plot (otra_rem)"
# Plot with title "Outlier Diagnosis Plot (remu_espec)"
# Plot with title "Outlier Diagnosis Plot (negocio)"
# Plot with title "Outlier Diagnosis Plot (noagrop)"
# Plot with title "Outlier Diagnosis Plot (industria)"
# Plot with title "Outlier Diagnosis Plot (comercio)"
# Plot with title "Outlier Diagnosis Plot (servicios)"
# Plot with title "Outlier Diagnosis Plot (agrope)"
# Plot with title "Outlier Diagnosis Plot (agricolas)"
# Plot with title "Outlier Diagnosis Plot (pecuarios)"
# Plot with title "Outlier Diagnosis Plot (reproducc)"
# Plot with title "Outlier Diagnosis Plot (pesca)"
# Plot with title "Outlier Diagnosis Plot (otros_trab)"
# Plot with title "Outlier Diagnosis Plot (rentas)"
# Plot with title "Outlier Diagnosis Plot (utilidad)"
# Plot with title "Outlier Diagnosis Plot (arrenda)"
# Plot with title "Outlier Diagnosis Plot (transfer)"
# Plot with title "Outlier Diagnosis Plot (jubilacion)"
# Plot with title "Outlier Diagnosis Plot (becas)"
# Plot with title "Outlier Diagnosis Plot (donativos)"
# Plot with title "Outlier Diagnosis Plot (remesas)"
# Plot with title "Outlier Diagnosis Plot (bene_gob)"
# Plot with title "Outlier Diagnosis Plot (transf_hog)"
# Plot with title "Outlier Diagnosis Plot (trans_inst)"
# Plot with title "Outlier Diagnosis Plot (estim_alqu)"
# Plot with title "Outlier Diagnosis Plot (otros_ing)"
# Plot with title "Outlier Diagnosis Plot (gasto_mon)"
# Plot with title "Outlier Diagnosis Plot (alimentos)"
# Plot with title "Outlier Diagnosis Plot (ali_dentro)"
# Plot with title "Outlier Diagnosis Plot (cereales)"
# Plot with title "Outlier Diagnosis Plot (carnes)"
# Plot with title "Outlier Diagnosis Plot (pescado)"
# Plot with title "Outlier Diagnosis Plot (leche)"
# Plot with title "Outlier Diagnosis Plot (huevo)"
# Plot with title "Outlier Diagnosis Plot (aceites)"
# Plot with title "Outlier Diagnosis Plot (tuberculo)"
# Plot with title "Outlier Diagnosis Plot (verduras)"
# Plot with title "Outlier Diagnosis Plot (frutas)"
# Plot with title "Outlier Diagnosis Plot (azucar)"
# Plot with title "Outlier Diagnosis Plot (cafe)"
# Plot with title "Outlier Diagnosis Plot (especias)"
# Plot with title "Outlier Diagnosis Plot (otros_alim)"
# Plot with title "Outlier Diagnosis Plot (bebidas)"
# Plot with title "Outlier Diagnosis Plot (ali_fuera)"
# Plot with title "Outlier Diagnosis Plot (tabaco)"
# Plot with title "Outlier Diagnosis Plot (vesti_calz)"
# Plot with title "Outlier Diagnosis Plot (vestido)"
# Plot with title "Outlier Diagnosis Plot (calzado)"
# Plot with title "Outlier Diagnosis Plot (vivienda)"
# Plot with title "Outlier Diagnosis Plot (alquiler)"
# Plot with title "Outlier Diagnosis Plot (pred_cons)"
# Plot with title "Outlier Diagnosis Plot (agua)"
# Plot with title "Outlier Diagnosis Plot (energia)"
# Plot with title "Outlier Diagnosis Plot (limpieza)"
# Plot with title "Outlier Diagnosis Plot (cuidados)"
# Plot with title "Outlier Diagnosis Plot (utensilios)"
# Plot with title "Outlier Diagnosis Plot (enseres)"
# Plot with title "Outlier Diagnosis Plot (salud)"
# Plot with title "Outlier Diagnosis Plot (atenc_ambu)"
# Plot with title "Outlier Diagnosis Plot (hospital)"
# Plot with title "Outlier Diagnosis Plot (medicinas)"
# Plot with title "Outlier Diagnosis Plot (transporte)"
# Plot with title "Outlier Diagnosis Plot (publico)"
# Plot with title "Outlier Diagnosis Plot (foraneo)"
# Plot with title "Outlier Diagnosis Plot (adqui_vehi)"
# Plot with title "Outlier Diagnosis Plot (mantenim)"
# Plot with title "Outlier Diagnosis Plot (refaccion)"
# Plot with title "Outlier Diagnosis Plot (combus)"
# Plot with title "Outlier Diagnosis Plot (comunica)"
# Plot with title "Outlier Diagnosis Plot (educa_espa)"
# Plot with title "Outlier Diagnosis Plot (educacion)"
# Plot with title "Outlier Diagnosis Plot (esparci)"
# Plot with title "Outlier Diagnosis Plot (paq_turist)"
# Plot with title "Outlier Diagnosis Plot (personales)"
# Plot with title "Outlier Diagnosis Plot (cuida_pers)"
# Plot with title "Outlier Diagnosis Plot (acces_pers)"
# Plot with title "Outlier Diagnosis Plot (otros_gas)"
# Plot with title "Outlier Diagnosis Plot (transf_gas)"
# Plot with title "Outlier Diagnosis Plot (percep_tot)"
# Plot with title "Outlier Diagnosis Plot (retiro_inv)"
# Plot with title "Outlier Diagnosis Plot (prestamos)"
# Plot with title "Outlier Diagnosis Plot (otras_perc)"
# Plot with title "Outlier Diagnosis Plot (ero_nm_viv)"
# Plot with title "Outlier Diagnosis Plot (ero_nm_hog)"
# Plot with title "Outlier Diagnosis Plot (erogac_tot)"
# Plot with title "Outlier Diagnosis Plot (cuota_viv)"
# Plot with title "Outlier Diagnosis Plot (mater_serv)"
# Plot with title "Outlier Diagnosis Plot (material)"
# Plot with title "Outlier Diagnosis Plot (servicio)"
# Plot with title "Outlier Diagnosis Plot (deposito)"
# Plot with title "Outlier Diagnosis Plot (prest_terc)"
# Plot with title "Outlier Diagnosis Plot (pago_tarje)"
# Plot with title "Outlier Diagnosis Plot (deudas)"
# Plot with title "Outlier Diagnosis Plot (balance)"
# Plot with title "Outlier Diagnosis Plot (otras_erog)"
# Plot with title "Outlier Diagnosis Plot (smg)"

# %%
diagnose_report(data)
# Out:
# processing file: C:\Users\Mary\AppData\Local\Temp\RtmpIXmZC9/DataDiagnosis_Report.Rnw
#   |.......................                                               |  33%
#   ordinary text without R code
#
#   |...............................................                       |  67%
# label: child-section-application (with options)
# List of 1
#  $ child: chr "01_Diagnose.Rnw"
# processing file: C:/Users/Mary/AppData/Local/Temp/RtmpIXmZC9/01_Diagnose.Rnw
#   |...                                                                   |   4%
#   ordinary text without R code
#
#   |......                                                                |   8%
# label: environment (with options)
# List of 3
#  $ echo   : logi FALSE
#  $ warning: logi FALSE
#  $ message: logi FALSE
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: 'kableExtra'
#
#
# The following object is masked from 'package:dplyr':
#
#     group_rows
#   |........                                                              |  12%
#   ordinary text without R code
#
#   |...........                                                           |  16%
# label: overview (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ results: chr "asis"
#
#   |..............                                                        |  20%
#   ordinary text without R code
#
#   |.................                                                     |  24%
# label: missing_data (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ results: chr "asis"
#
#   |....................                                                  |  28%
#   ordinary text without R code
#
#   |......................                                                |  32%
# label: unique_date_category (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ results: chr "asis"
#
#   |.........................                                             |  36%
#   ordinary text without R code
#
#   |............................                                          |  40%
# label: unique_data_numeric (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ results: chr "asis"
#
#   |...............................                                       |  44%
#   ordinary text without R code
#
#   |..................................                                    |  48%
# label: diagnose_catagory (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ results: chr "asis"
# There is no categorical variable in the data or variable list.
#   |....................................                                  |  52%
#   ordinary text without R code
#
#   |.......................................                               |  56%
# label: diagnose_numeric (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ results: chr "asis"
#
#   |..........................................                            |  60%
#   ordinary text without R code
#
#   |.............................................                         |  64%
# label: numeric_zero (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ results: chr "asis"
#
#   |................................................                      |  68%
#   ordinary text without R code
#
#   |..................................................                    |  72%
# label: numeric_minus (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ results: chr "asis"
#
#   |.....................................................                 |  76%
#   ordinary text without R code
#
#   |........................................................              |  80%
# label: outliers (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ results: chr "asis"
#
#   |...........................................................           |  84%
#   ordinary text without R code
#
#   |..............................................................        |  88%
# label: detail_outliers (with options)
# List of 5
#  $ tidy     : logi TRUE
#  $ tidy.opts: language list(width.cutoff = 65)
#  $ size     : chr "small"
#  $ echo     : logi FALSE
#  $ results  : chr "asis"
#
#   |................................................................      |  92%
#   ordinary text without R code
#
#   |...................................................................   |  96%
# label: option_undo (with options)
# List of 1
#  $ echo: logi FALSE
#
#   |......................................................................| 100%
#   ordinary text without R code
#
#
#   |......................................................................| 100%
#   ordinary text without R code
# output file: C:\Users\Mary\AppData\Local\Temp\RtmpIXmZC9/DataDiagnosis_Report.tex
